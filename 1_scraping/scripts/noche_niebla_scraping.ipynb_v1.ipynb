# %%
# !pip install requests beautifulsoup4 pandas

# %% [markdown]
# B.L.
# "noche_niebla_scraping.ipynb_v1" scrapes data from the Noche y Niebla database (https://base.nocheyniebla.org/casos).
#
# **How it works**
#
# The script automatically queries the database for cases in a given date range.
#
# Default range: 1 December 1999 - 31 December 2024
# (You can change this in the overall_start / overall_end variables).
# To avoid exceeding the server’s row limit (≈2000 cases per query), the script splits the scraping into ~2-month intervals, then merges the results.
#
# **Output**
#
# By default, results are appended into a single CSV file: "nocheyniebla_casos_1999_2024.csv"
# Alternatively, you can save quarterly CSVs in casos_quarterly_csvs/ by setting: APPEND_TO_SINGLE_CSV = False
#
# **Data format**
#
# The output preserves the original table headers from the website:
#
# Fecha del hecho
#
# Ubicaciones
#
# P. Responsables
#
# Tipificación
# Víctimas
# Descripción
# Acciones
#
# **Reproducibility**
#
# To reproduce results, follow the step-by-step comments inside the notebook.
#
# The script uses:
#
# requests + BeautifulSoup for scraping
# pandas for data storage/export
# datetime for date range handling

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from datetime import datetime, timedelta
import os

base_url = "https://base.nocheyniebla.org/casos"

# These are the common query parameters (except date fields, which we fill per iteration). The parameters are based on the query filter
query_params = {
    "filtro[apellidos]": "",
    "filtro[departamento_id]": "",
    "filtro[descripcion]": "",
    "filtro[inc_fecha]": "1",
    "filtro[inc_memo]": "1",
    "filtro[inc_presponsables]": "1",
    "filtro[inc_tipificacion]": "1",
    "filtro[inc_ubicaciones]": "1",
    "filtro[inc_victimas]": "1",
    "filtro[municipio_id]": "",
    "filtro[nombres]": "",
    "filtro[orden]": "fecha",
    "filtro[pais_id]": "170",
    "filtro[presponsable_id][]": "",
    "filtro[q]": "",
    "filtro[rangoedad_id]": "",
    "filtro[sectorsocial_id]": "",
    "filtro[sexo]": "",
    "filtro[tviolencia_id]": "Z"
}

# --- SETTINGS ---
# Start and end of the whole period the format is (yyyy, m,d). 
overall_start = datetime(1999, 12, 1)
overall_end = datetime(2024, 12, 31)
three_months = timedelta(days=60)  # Close enough for 2 months (this is to avoid exeeding the limit of 2000 cases)

# Directory for individual CSVs
output_dir = 'casos_quarterly_csvs'
os.makedirs(output_dir, exist_ok=True)

# For a single, growing CSV, this should be set to True
# Otherwise, it saves each quarter to its own file (recommended for automation, then merge later)
APPEND_TO_SINGLE_CSV = True
ALL_ROWS = []
HEADERS = []

# --- MAIN LOOP ---
current_start = overall_start

while current_start < overall_end:
    # Calculate end of period (2 months later, or end of year)
    current_end = min(current_start + three_months, overall_end)
    print(f"\nProcessing {current_start.date()} to {current_end.date()}...")

    # Set dates auto, (don't change this, change the date above in "settings")
    fechaini = current_start.strftime('%Y-%m-%d')
    fechafin = current_end.strftime('%Y-%m-%d')
    query_params['filtro[fechaini]'] = fechaini
    query_params['filtro[fechafin]'] = fechafin

    all_rows = []
    headers = []
    page_number = 1
    new_entries = 1  # Arbitrary positive integer to start loop
    session_headers = HEADERS.copy()  # Copy global headers, if available

    while new_entries > 0:
        query_params['pagina'] = str(page_number)
        try:
            response = requests.get(base_url, params=query_params, timeout=60)
            response.raise_for_status()
        except Exception as e:
            print(f"Failed to fetch page {page_number}: {e}")
            break

        soup = BeautifulSoup(response.text, 'html.parser')
        table = soup.find('table')

        if not table:
            print(f"No table found on page {page_number}, moving to next date range.")
            new_entries = 0
            break

        if not headers:
            thead = table.find('thead')
            if thead:
                headers = [th.text.strip() for th in thead.find('tr').find_all('th')]
            else:
                headers = [th.text.strip() for th in table.find('tr').find_all('th')]
            session_headers = headers.copy()
            if not HEADERS:  
                HEADERS = headers.copy()

        new_entries = 0
        for tr in table.find_all('tr')[1:]:
            row = [td.text.strip() for td in tr.find_all('td')]
            if row:
                all_rows.append(row)
                new_entries += 1
        print(f"Scraped {new_entries} rows from {current_start.date()}–{current_end.date()} (page {page_number})")
        page_number += 1

    # Save results for this period
    if headers and all_rows:
        df = pd.DataFrame(all_rows, columns=session_headers)
        if APPEND_TO_SINGLE_CSV:
            ALL_ROWS.extend(all_rows)
            print(f"Quarter {fechaini}_{fechafin} appended to global dataset.")
        else:
            # Save individual quarterly CSV
            filename = os.path.join(output_dir, f"{fechaini}_{fechafin}.csv")
            df.to_csv(filename, index=False)
            print(f"Quarterly data saved to {filename}")

    else:
        print(f"No data found for {fechaini}–{fechafin}")

    # Moving to next period
    current_start = current_end + timedelta(days=1)  # Start next period on the next day

# After all periods (range of dates), optionally save a single combined CSV (here this is set to true above)
if APPEND_TO_SINGLE_CSV and ALL_ROWS and HEADERS:
    combined_df = pd.DataFrame(ALL_ROWS, columns=HEADERS)
    combined_df.to_csv('nocheyniebla_casos_1999_2024.csv', index=False) #this should be changed for want a new filename
    print("\nAll periods saved to 'nocheyniebla_casos_1999_2024.csv'.")
else:
    print("\nAll periods processed.")

print("\nComplete!")
# Out:
# Processing 1999-12-01 to 2000-01-30...
# Scraped 20 rows from 1999-12-01–2000-01-30 (page 1)
# Scraped 20 rows from 1999-12-01–2000-01-30 (page 2)
# Scraped 20 rows from 1999-12-01–2000-01-30 (page 3)
# Scraped 20 rows from 1999-12-01–2000-01-30 (page 4)
# Scraped 20 rows from 1999-12-01–2000-01-30 (page 5)
# Scraped 20 rows from 1999-12-01–2000-01-30 (page 6)
# Scraped 20 rows from 1999-12-01–2000-01-30 (page 7)
# Scraped 20 rows from 1999-12-01–2000-01-30 (page 8)
# Scraped 20 rows from 1999-12-01–2000-01-30 (page 9)
# Scraped 20 rows from 1999-12-01–2000-01-30 (page 10)
# Scraped 20 rows from 1999-12-01–2000-01-30 (page 11)
# Scraped 20 rows from 1999-12-01–2000-01-30 (page 12)
# Scraped 20 rows from 1999-12-01–2000-01-30 (page 13)
# Scraped 20 rows from 1999-12-01–2000-01-30 (page 14)
# Scraped 20 rows from 1999-12-01–2000-01-30 (page 15)
# Scraped 20 rows from 1999-12-01–2000-01-30 (page 16)
# Scraped 20 rows from 1999-12-01–2000-01-30 (page 17)
# Scraped 20 rows from 1999-12-01–2000-01-30 (page 18)
# Scraped 20 rows from 1999-12-01–2000-01-30 (page 19)
# Scraped 20 rows from 1999-12-01–2000-01-30 (page 20)
# Scraped 20 rows from 1999-12-01–2000-01-30 (page 21)
# Scraped 13 rows from 1999-12-01–2000-01-30 (page 22)
# Scraped 0 rows from 1999-12-01–2000-01-30 (page 23)
# Quarter 1999-12-01_2000-01-30 appended to global dataset.
#
# Processing 2000-01-31 to 2000-03-31...
# Scraped 20 rows from 2000-01-31–2000-03-31 (page 1)
# Scraped 20 rows from 2000-01-31–2000-03-31 (page 2)
# Scraped 20 rows from 2000-01-31–2000-03-31 (page 3)
# Scraped 20 rows from 2000-01-31–2000-03-31 (page 4)
# Scraped 20 rows from 2000-01-31–2000-03-31 (page 5)
# Scraped 20 rows from 2000-01-31–2000-03-31 (page 6)
# Scraped 20 rows from 2000-01-31–2000-03-31 (page 7)
# Scraped 20 rows from 2000-01-31–2000-03-31 (page 8)
# Scraped 20 rows from 2000-01-31–2000-03-31 (page 9)
# Scraped 20 rows from 2000-01-31–2000-03-31 (page 10)
# Scraped 20 rows from 2000-01-31–2000-03-31 (page 11)
# Scraped 20 rows from 2000-01-31–2000-03-31 (page 12)
# Scraped 20 rows from 2000-01-31–2000-03-31 (page 13)
# Scraped 20 rows from 2000-01-31–2000-03-31 (page 14)
# Scraped 20 rows from 2000-01-31–2000-03-31 (page 15)
# Scraped 20 rows from 2000-01-31–2000-03-31 (page 16)
# Scraped 20 rows from 2000-01-31–2000-03-31 (page 17)
# Scraped 20 rows from 2000-01-31–2000-03-31 (page 18)
# Scraped 20 rows from 2000-01-31–2000-03-31 (page 19)
# Scraped 20 rows from 2000-01-31–2000-03-31 (page 20)
# Scraped 20 rows from 2000-01-31–2000-03-31 (page 21)
# Scraped 20 rows from 2000-01-31–2000-03-31 (page 22)
# Scraped 20 rows from 2000-01-31–2000-03-31 (page 23)
# Scraped 20 rows from 2000-01-31–2000-03-31 (page 24)
# Scraped 20 rows from 2000-01-31–2000-03-31 (page 25)
# Scraped 20 rows from 2000-01-31–2000-03-31 (page 26)
# Scraped 20 rows from 2000-01-31–2000-03-31 (page 27)
# Scraped 20 rows from 2000-01-31–2000-03-31 (page 28)
# Scraped 20 rows from 2000-01-31–2000-03-31 (page 29)
# Scraped 20 rows from 2000-01-31–2000-03-31 (page 30)
# Scraped 20 rows from 2000-01-31–2000-03-31 (page 31)
# Scraped 20 rows from 2000-01-31–2000-03-31 (page 32)
# Scraped 20 rows from 2000-01-31–2000-03-31 (page 33)
# Scraped 14 rows from 2000-01-31–2000-03-31 (page 34)
# Scraped 0 rows from 2000-01-31–2000-03-31 (page 35)
# Quarter 2000-01-31_2000-03-31 appended to global dataset.
#
# Processing 2000-04-01 to 2000-05-31...
# Scraped 20 rows from 2000-04-01–2000-05-31 (page 1)
# Scraped 20 rows from 2000-04-01–2000-05-31 (page 2)
# Scraped 20 rows from 2000-04-01–2000-05-31 (page 3)
# Scraped 20 rows from 2000-04-01–2000-05-31 (page 4)
# Scraped 20 rows from 2000-04-01–2000-05-31 (page 5)
# Scraped 20 rows from 2000-04-01–2000-05-31 (page 6)
# Scraped 20 rows from 2000-04-01–2000-05-31 (page 7)
# Scraped 20 rows from 2000-04-01–2000-05-31 (page 8)
# Scraped 20 rows from 2000-04-01–2000-05-31 (page 9)
# Scraped 20 rows from 2000-04-01–2000-05-31 (page 10)
# Scraped 20 rows from 2000-04-01–2000-05-31 (page 11)
# Scraped 20 rows from 2000-04-01–2000-05-31 (page 12)
# Scraped 20 rows from 2000-04-01–2000-05-31 (page 13)
# Scraped 20 rows from 2000-04-01–2000-05-31 (page 14)
# Scraped 20 rows from 2000-04-01–2000-05-31 (page 15)
# Scraped 20 rows from 2000-04-01–2000-05-31 (page 16)
# Scraped 20 rows from 2000-04-01–2000-05-31 (page 17)
# Scraped 20 rows from 2000-04-01–2000-05-31 (page 18)
# Scraped 20 rows from 2000-04-01–2000-05-31 (page 19)
# Scraped 20 rows from 2000-04-01–2000-05-31 (page 20)
# Scraped 20 rows from 2000-04-01–2000-05-31 (page 21)
# Scraped 20 rows from 2000-04-01–2000-05-31 (page 22)
# Scraped 20 rows from 2000-04-01–2000-05-31 (page 23)
# Scraped 20 rows from 2000-04-01–2000-05-31 (page 24)
# Scraped 20 rows from 2000-04-01–2000-05-31 (page 25)
# Scraped 20 rows from 2000-04-01–2000-05-31 (page 26)
# Scraped 20 rows from 2000-04-01–2000-05-31 (page 27)
# Scraped 20 rows from 2000-04-01–2000-05-31 (page 28)
# Scraped 20 rows from 2000-04-01–2000-05-31 (page 29)
# Scraped 20 rows from 2000-04-01–2000-05-31 (page 30)
# Scraped 20 rows from 2000-04-01–2000-05-31 (page 31)
# Scraped 20 rows from 2000-04-01–2000-05-31 (page 32)
# Scraped 20 rows from 2000-04-01–2000-05-31 (page 33)
# Scraped 20 rows from 2000-04-01–2000-05-31 (page 34)
# Scraped 20 rows from 2000-04-01–2000-05-31 (page 35)
# Scraped 20 rows from 2000-04-01–2000-05-31 (page 36)
# Scraped 20 rows from 2000-04-01–2000-05-31 (page 37)
# Scraped 6 rows from 2000-04-01–2000-05-31 (page 38)
# Scraped 0 rows from 2000-04-01–2000-05-31 (page 39)
# Quarter 2000-04-01_2000-05-31 appended to global dataset.
#
# Processing 2000-06-01 to 2000-07-31...
# Scraped 20 rows from 2000-06-01–2000-07-31 (page 1)
# Scraped 20 rows from 2000-06-01–2000-07-31 (page 2)
# Scraped 20 rows from 2000-06-01–2000-07-31 (page 3)
# Scraped 20 rows from 2000-06-01–2000-07-31 (page 4)
# Scraped 20 rows from 2000-06-01–2000-07-31 (page 5)
# Scraped 20 rows from 2000-06-01–2000-07-31 (page 6)
# Scraped 20 rows from 2000-06-01–2000-07-31 (page 7)
# Scraped 20 rows from 2000-06-01–2000-07-31 (page 8)
# Scraped 20 rows from 2000-06-01–2000-07-31 (page 9)
# Scraped 20 rows from 2000-06-01–2000-07-31 (page 10)
# Scraped 20 rows from 2000-06-01–2000-07-31 (page 11)
# Scraped 20 rows from 2000-06-01–2000-07-31 (page 12)
# Scraped 20 rows from 2000-06-01–2000-07-31 (page 13)
# Scraped 20 rows from 2000-06-01–2000-07-31 (page 14)
# Scraped 20 rows from 2000-06-01–2000-07-31 (page 15)
# Scraped 20 rows from 2000-06-01–2000-07-31 (page 16)
# Scraped 20 rows from 2000-06-01–2000-07-31 (page 17)
# Scraped 20 rows from 2000-06-01–2000-07-31 (page 18)
# Scraped 20 rows from 2000-06-01–2000-07-31 (page 19)
# Scraped 20 rows from 2000-06-01–2000-07-31 (page 20)
# Scraped 20 rows from 2000-06-01–2000-07-31 (page 21)
# Scraped 20 rows from 2000-06-01–2000-07-31 (page 22)
# Scraped 20 rows from 2000-06-01–2000-07-31 (page 23)
# Scraped 20 rows from 2000-06-01–2000-07-31 (page 24)
# Scraped 20 rows from 2000-06-01–2000-07-31 (page 25)
# Scraped 20 rows from 2000-06-01–2000-07-31 (page 26)
# Scraped 20 rows from 2000-06-01–2000-07-31 (page 27)
# Scraped 20 rows from 2000-06-01–2000-07-31 (page 28)
# Scraped 20 rows from 2000-06-01–2000-07-31 (page 29)
# Scraped 20 rows from 2000-06-01–2000-07-31 (page 30)
# Scraped 20 rows from 2000-06-01–2000-07-31 (page 31)
# Scraped 20 rows from 2000-06-01–2000-07-31 (page 32)
# Scraped 20 rows from 2000-06-01–2000-07-31 (page 33)
# Scraped 20 rows from 2000-06-01–2000-07-31 (page 34)
# Scraped 20 rows from 2000-06-01–2000-07-31 (page 35)
# Scraped 20 rows from 2000-06-01–2000-07-31 (page 36)
# Scraped 20 rows from 2000-06-01–2000-07-31 (page 37)
# Scraped 20 rows from 2000-06-01–2000-07-31 (page 38)
# Scraped 20 rows from 2000-06-01–2000-07-31 (page 39)
# Scraped 20 rows from 2000-06-01–2000-07-31 (page 40)
# Scraped 10 rows from 2000-06-01–2000-07-31 (page 41)
# Scraped 0 rows from 2000-06-01–2000-07-31 (page 42)
# Quarter 2000-06-01_2000-07-31 appended to global dataset.
#
# Processing 2000-08-01 to 2000-09-30...
# Scraped 20 rows from 2000-08-01–2000-09-30 (page 1)
# Scraped 20 rows from 2000-08-01–2000-09-30 (page 2)
# Scraped 20 rows from 2000-08-01–2000-09-30 (page 3)
# Scraped 20 rows from 2000-08-01–2000-09-30 (page 4)
# Scraped 20 rows from 2000-08-01–2000-09-30 (page 5)
# Scraped 20 rows from 2000-08-01–2000-09-30 (page 6)
# Scraped 20 rows from 2000-08-01–2000-09-30 (page 7)
# Scraped 20 rows from 2000-08-01–2000-09-30 (page 8)
# Scraped 20 rows from 2000-08-01–2000-09-30 (page 9)
# Scraped 20 rows from 2000-08-01–2000-09-30 (page 10)
# Scraped 20 rows from 2000-08-01–2000-09-30 (page 11)
# Scraped 20 rows from 2000-08-01–2000-09-30 (page 12)
# Scraped 20 rows from 2000-08-01–2000-09-30 (page 13)
# Scraped 20 rows from 2000-08-01–2000-09-30 (page 14)
# Scraped 20 rows from 2000-08-01–2000-09-30 (page 15)
# Scraped 20 rows from 2000-08-01–2000-09-30 (page 16)
# Scraped 20 rows from 2000-08-01–2000-09-30 (page 17)
# Scraped 20 rows from 2000-08-01–2000-09-30 (page 18)
# Scraped 20 rows from 2000-08-01–2000-09-30 (page 19)
# Scraped 20 rows from 2000-08-01–2000-09-30 (page 20)
# Scraped 20 rows from 2000-08-01–2000-09-30 (page 21)
# Scraped 20 rows from 2000-08-01–2000-09-30 (page 22)
# Scraped 20 rows from 2000-08-01–2000-09-30 (page 23)
# Scraped 20 rows from 2000-08-01–2000-09-30 (page 24)
# Scraped 20 rows from 2000-08-01–2000-09-30 (page 25)
# Scraped 20 rows from 2000-08-01–2000-09-30 (page 26)
# Scraped 20 rows from 2000-08-01–2000-09-30 (page 27)
# Scraped 20 rows from 2000-08-01–2000-09-30 (page 28)
# Scraped 20 rows from 2000-08-01–2000-09-30 (page 29)
# Scraped 20 rows from 2000-08-01–2000-09-30 (page 30)
# Scraped 20 rows from 2000-08-01–2000-09-30 (page 31)
# Scraped 20 rows from 2000-08-01–2000-09-30 (page 32)
# Scraped 20 rows from 2000-08-01–2000-09-30 (page 33)
# Scraped 20 rows from 2000-08-01–2000-09-30 (page 34)
# Scraped 20 rows from 2000-08-01–2000-09-30 (page 35)
# Scraped 20 rows from 2000-08-01–2000-09-30 (page 36)
# Scraped 20 rows from 2000-08-01–2000-09-30 (page 37)
# Scraped 20 rows from 2000-08-01–2000-09-30 (page 38)
# Scraped 20 rows from 2000-08-01–2000-09-30 (page 39)
# Scraped 20 rows from 2000-08-01–2000-09-30 (page 40)
# Scraped 20 rows from 2000-08-01–2000-09-30 (page 41)
# Scraped 20 rows from 2000-08-01–2000-09-30 (page 42)
# Scraped 20 rows from 2000-08-01–2000-09-30 (page 43)
# Scraped 20 rows from 2000-08-01–2000-09-30 (page 44)
# Scraped 10 rows from 2000-08-01–2000-09-30 (page 45)
# Scraped 0 rows from 2000-08-01–2000-09-30 (page 46)
# Quarter 2000-08-01_2000-09-30 appended to global dataset.
#
# Processing 2000-10-01 to 2000-11-30...
# Scraped 20 rows from 2000-10-01–2000-11-30 (page 1)
# Scraped 20 rows from 2000-10-01–2000-11-30 (page 2)
# Scraped 20 rows from 2000-10-01–2000-11-30 (page 3)
# Scraped 20 rows from 2000-10-01–2000-11-30 (page 4)
# Scraped 20 rows from 2000-10-01–2000-11-30 (page 5)
# Scraped 20 rows from 2000-10-01–2000-11-30 (page 6)
# Scraped 20 rows from 2000-10-01–2000-11-30 (page 7)
# Scraped 20 rows from 2000-10-01–2000-11-30 (page 8)
# Scraped 20 rows from 2000-10-01–2000-11-30 (page 9)
# Scraped 20 rows from 2000-10-01–2000-11-30 (page 10)
# Scraped 20 rows from 2000-10-01–2000-11-30 (page 11)
# Scraped 20 rows from 2000-10-01–2000-11-30 (page 12)
# Scraped 20 rows from 2000-10-01–2000-11-30 (page 13)
# Scraped 20 rows from 2000-10-01–2000-11-30 (page 14)
# Scraped 20 rows from 2000-10-01–2000-11-30 (page 15)
# Scraped 20 rows from 2000-10-01–2000-11-30 (page 16)
# Scraped 20 rows from 2000-10-01–2000-11-30 (page 17)
# Scraped 20 rows from 2000-10-01–2000-11-30 (page 18)
# Scraped 20 rows from 2000-10-01–2000-11-30 (page 19)
# Scraped 20 rows from 2000-10-01–2000-11-30 (page 20)
# Scraped 20 rows from 2000-10-01–2000-11-30 (page 21)
# Scraped 20 rows from 2000-10-01–2000-11-30 (page 22)
# Scraped 20 rows from 2000-10-01–2000-11-30 (page 23)
# Scraped 20 rows from 2000-10-01–2000-11-30 (page 24)
# Scraped 20 rows from 2000-10-01–2000-11-30 (page 25)
# Scraped 20 rows from 2000-10-01–2000-11-30 (page 26)
# Scraped 20 rows from 2000-10-01–2000-11-30 (page 27)
# Scraped 20 rows from 2000-10-01–2000-11-30 (page 28)
# Scraped 20 rows from 2000-10-01–2000-11-30 (page 29)
# Scraped 20 rows from 2000-10-01–2000-11-30 (page 30)
# Scraped 20 rows from 2000-10-01–2000-11-30 (page 31)
# Scraped 20 rows from 2000-10-01–2000-11-30 (page 32)
# Scraped 20 rows from 2000-10-01–2000-11-30 (page 33)
# Scraped 20 rows from 2000-10-01–2000-11-30 (page 34)
# Scraped 20 rows from 2000-10-01–2000-11-30 (page 35)
# Scraped 20 rows from 2000-10-01–2000-11-30 (page 36)
# Scraped 20 rows from 2000-10-01–2000-11-30 (page 37)
# Scraped 20 rows from 2000-10-01–2000-11-30 (page 38)
# Scraped 5 rows from 2000-10-01–2000-11-30 (page 39)
# Scraped 0 rows from 2000-10-01–2000-11-30 (page 40)
# Quarter 2000-10-01_2000-11-30 appended to global dataset.
#
# Processing 2000-12-01 to 2001-01-30...
# Scraped 20 rows from 2000-12-01–2001-01-30 (page 1)
# Scraped 20 rows from 2000-12-01–2001-01-30 (page 2)
# Scraped 20 rows from 2000-12-01–2001-01-30 (page 3)
# Scraped 20 rows from 2000-12-01–2001-01-30 (page 4)
# Scraped 20 rows from 2000-12-01–2001-01-30 (page 5)
# Scraped 20 rows from 2000-12-01–2001-01-30 (page 6)
# Scraped 20 rows from 2000-12-01–2001-01-30 (page 7)
# Scraped 20 rows from 2000-12-01–2001-01-30 (page 8)
# Scraped 20 rows from 2000-12-01–2001-01-30 (page 9)
# Scraped 20 rows from 2000-12-01–2001-01-30 (page 10)
# Scraped 20 rows from 2000-12-01–2001-01-30 (page 11)
# Scraped 20 rows from 2000-12-01–2001-01-30 (page 12)
# Scraped 20 rows from 2000-12-01–2001-01-30 (page 13)
# Scraped 20 rows from 2000-12-01–2001-01-30 (page 14)
# Scraped 20 rows from 2000-12-01–2001-01-30 (page 15)
# Scraped 20 rows from 2000-12-01–2001-01-30 (page 16)
# Scraped 20 rows from 2000-12-01–2001-01-30 (page 17)
# Scraped 20 rows from 2000-12-01–2001-01-30 (page 18)
# Scraped 20 rows from 2000-12-01–2001-01-30 (page 19)
# Scraped 20 rows from 2000-12-01–2001-01-30 (page 20)
# Scraped 20 rows from 2000-12-01–2001-01-30 (page 21)
# Scraped 20 rows from 2000-12-01–2001-01-30 (page 22)
# Scraped 20 rows from 2000-12-01–2001-01-30 (page 23)
# Scraped 20 rows from 2000-12-01–2001-01-30 (page 24)
# Scraped 20 rows from 2000-12-01–2001-01-30 (page 25)
# Scraped 20 rows from 2000-12-01–2001-01-30 (page 26)
# Scraped 20 rows from 2000-12-01–2001-01-30 (page 27)
# Scraped 20 rows from 2000-12-01–2001-01-30 (page 28)
# Scraped 20 rows from 2000-12-01–2001-01-30 (page 29)
# Scraped 20 rows from 2000-12-01–2001-01-30 (page 30)
# Scraped 20 rows from 2000-12-01–2001-01-30 (page 31)
# Scraped 20 rows from 2000-12-01–2001-01-30 (page 32)
# Scraped 20 rows from 2000-12-01–2001-01-30 (page 33)
# Scraped 20 rows from 2000-12-01–2001-01-30 (page 34)
# Scraped 20 rows from 2000-12-01–2001-01-30 (page 35)
# Scraped 11 rows from 2000-12-01–2001-01-30 (page 36)
# Scraped 0 rows from 2000-12-01–2001-01-30 (page 37)
# Quarter 2000-12-01_2001-01-30 appended to global dataset.
#
# Processing 2001-01-31 to 2001-04-01...
# Scraped 20 rows from 2001-01-31–2001-04-01 (page 1)
# Scraped 20 rows from 2001-01-31–2001-04-01 (page 2)
# Scraped 20 rows from 2001-01-31–2001-04-01 (page 3)
# Scraped 20 rows from 2001-01-31–2001-04-01 (page 4)
# Scraped 20 rows from 2001-01-31–2001-04-01 (page 5)
# Scraped 20 rows from 2001-01-31–2001-04-01 (page 6)
# Scraped 20 rows from 2001-01-31–2001-04-01 (page 7)
# Scraped 20 rows from 2001-01-31–2001-04-01 (page 8)
# Scraped 20 rows from 2001-01-31–2001-04-01 (page 9)
# Scraped 20 rows from 2001-01-31–2001-04-01 (page 10)
# Scraped 20 rows from 2001-01-31–2001-04-01 (page 11)
# Scraped 20 rows from 2001-01-31–2001-04-01 (page 12)
# Scraped 20 rows from 2001-01-31–2001-04-01 (page 13)
# Scraped 20 rows from 2001-01-31–2001-04-01 (page 14)
# Scraped 20 rows from 2001-01-31–2001-04-01 (page 15)
# Scraped 20 rows from 2001-01-31–2001-04-01 (page 16)
# Scraped 20 rows from 2001-01-31–2001-04-01 (page 17)
# Scraped 20 rows from 2001-01-31–2001-04-01 (page 18)
# Scraped 20 rows from 2001-01-31–2001-04-01 (page 19)
# Scraped 20 rows from 2001-01-31–2001-04-01 (page 20)
# Scraped 20 rows from 2001-01-31–2001-04-01 (page 21)
# Scraped 20 rows from 2001-01-31–2001-04-01 (page 22)
# Scraped 20 rows from 2001-01-31–2001-04-01 (page 23)
# Scraped 20 rows from 2001-01-31–2001-04-01 (page 24)
# Scraped 20 rows from 2001-01-31–2001-04-01 (page 25)
# Scraped 20 rows from 2001-01-31–2001-04-01 (page 26)
# Scraped 20 rows from 2001-01-31–2001-04-01 (page 27)
# Scraped 20 rows from 2001-01-31–2001-04-01 (page 28)
# Scraped 20 rows from 2001-01-31–2001-04-01 (page 29)
# Scraped 20 rows from 2001-01-31–2001-04-01 (page 30)
# Scraped 20 rows from 2001-01-31–2001-04-01 (page 31)
# Scraped 20 rows from 2001-01-31–2001-04-01 (page 32)
# Scraped 20 rows from 2001-01-31–2001-04-01 (page 33)
# Scraped 20 rows from 2001-01-31–2001-04-01 (page 34)
# Scraped 20 rows from 2001-01-31–2001-04-01 (page 35)
# Scraped 20 rows from 2001-01-31–2001-04-01 (page 36)
# Scraped 20 rows from 2001-01-31–2001-04-01 (page 37)
# Scraped 20 rows from 2001-01-31–2001-04-01 (page 38)
# Scraped 20 rows from 2001-01-31–2001-04-01 (page 39)
# Scraped 20 rows from 2001-01-31–2001-04-01 (page 40)
# Scraped 20 rows from 2001-01-31–2001-04-01 (page 41)
# Scraped 20 rows from 2001-01-31–2001-04-01 (page 42)
# Scraped 20 rows from 2001-01-31–2001-04-01 (page 43)
# Scraped 20 rows from 2001-01-31–2001-04-01 (page 44)
# Scraped 20 rows from 2001-01-31–2001-04-01 (page 45)
# Scraped 20 rows from 2001-01-31–2001-04-01 (page 46)
# Scraped 20 rows from 2001-01-31–2001-04-01 (page 47)
# Scraped 20 rows from 2001-01-31–2001-04-01 (page 48)
# Scraped 20 rows from 2001-01-31–2001-04-01 (page 49)
# Scraped 18 rows from 2001-01-31–2001-04-01 (page 50)
# Scraped 0 rows from 2001-01-31–2001-04-01 (page 51)
# Quarter 2001-01-31_2001-04-01 appended to global dataset.
#
# Processing 2001-04-02 to 2001-06-01...
# Scraped 20 rows from 2001-04-02–2001-06-01 (page 1)
# Scraped 20 rows from 2001-04-02–2001-06-01 (page 2)
# Scraped 20 rows from 2001-04-02–2001-06-01 (page 3)
# Scraped 20 rows from 2001-04-02–2001-06-01 (page 4)
# Scraped 20 rows from 2001-04-02–2001-06-01 (page 5)
# Scraped 20 rows from 2001-04-02–2001-06-01 (page 6)
# Scraped 20 rows from 2001-04-02–2001-06-01 (page 7)
# Scraped 20 rows from 2001-04-02–2001-06-01 (page 8)
# Scraped 20 rows from 2001-04-02–2001-06-01 (page 9)
# Scraped 20 rows from 2001-04-02–2001-06-01 (page 10)
# Scraped 20 rows from 2001-04-02–2001-06-01 (page 11)
# Scraped 20 rows from 2001-04-02–2001-06-01 (page 12)
# Scraped 20 rows from 2001-04-02–2001-06-01 (page 13)
# Scraped 20 rows from 2001-04-02–2001-06-01 (page 14)
# Scraped 20 rows from 2001-04-02–2001-06-01 (page 15)
# Scraped 20 rows from 2001-04-02–2001-06-01 (page 16)
# Scraped 20 rows from 2001-04-02–2001-06-01 (page 17)
# Scraped 20 rows from 2001-04-02–2001-06-01 (page 18)
# Scraped 20 rows from 2001-04-02–2001-06-01 (page 19)
# Scraped 20 rows from 2001-04-02–2001-06-01 (page 20)
# Scraped 20 rows from 2001-04-02–2001-06-01 (page 21)
# Scraped 20 rows from 2001-04-02–2001-06-01 (page 22)
# Scraped 20 rows from 2001-04-02–2001-06-01 (page 23)
# Scraped 20 rows from 2001-04-02–2001-06-01 (page 24)
# Scraped 20 rows from 2001-04-02–2001-06-01 (page 25)
# Scraped 20 rows from 2001-04-02–2001-06-01 (page 26)
# Scraped 20 rows from 2001-04-02–2001-06-01 (page 27)
# Scraped 20 rows from 2001-04-02–2001-06-01 (page 28)
# Scraped 20 rows from 2001-04-02–2001-06-01 (page 29)
# Scraped 20 rows from 2001-04-02–2001-06-01 (page 30)
# Scraped 20 rows from 2001-04-02–2001-06-01 (page 31)
# Scraped 20 rows from 2001-04-02–2001-06-01 (page 32)
# Scraped 20 rows from 2001-04-02–2001-06-01 (page 33)
# Scraped 20 rows from 2001-04-02–2001-06-01 (page 34)
# Scraped 20 rows from 2001-04-02–2001-06-01 (page 35)
# Scraped 20 rows from 2001-04-02–2001-06-01 (page 36)
# Scraped 20 rows from 2001-04-02–2001-06-01 (page 37)
# Scraped 20 rows from 2001-04-02–2001-06-01 (page 38)
# Scraped 20 rows from 2001-04-02–2001-06-01 (page 39)
# Scraped 20 rows from 2001-04-02–2001-06-01 (page 40)
# Scraped 20 rows from 2001-04-02–2001-06-01 (page 41)
# Scraped 20 rows from 2001-04-02–2001-06-01 (page 42)
# Scraped 20 rows from 2001-04-02–2001-06-01 (page 43)
# Scraped 20 rows from 2001-04-02–2001-06-01 (page 44)
# Scraped 20 rows from 2001-04-02–2001-06-01 (page 45)
# Scraped 6 rows from 2001-04-02–2001-06-01 (page 46)
# Scraped 0 rows from 2001-04-02–2001-06-01 (page 47)
# Quarter 2001-04-02_2001-06-01 appended to global dataset.
#
# Processing 2001-06-02 to 2001-08-01...
# Scraped 20 rows from 2001-06-02–2001-08-01 (page 1)
# Scraped 20 rows from 2001-06-02–2001-08-01 (page 2)
# Scraped 20 rows from 2001-06-02–2001-08-01 (page 3)
# Scraped 20 rows from 2001-06-02–2001-08-01 (page 4)
# Scraped 20 rows from 2001-06-02–2001-08-01 (page 5)
# Scraped 20 rows from 2001-06-02–2001-08-01 (page 6)
# Scraped 20 rows from 2001-06-02–2001-08-01 (page 7)
# Scraped 20 rows from 2001-06-02–2001-08-01 (page 8)
# Scraped 20 rows from 2001-06-02–2001-08-01 (page 9)
# Scraped 20 rows from 2001-06-02–2001-08-01 (page 10)
# Scraped 20 rows from 2001-06-02–2001-08-01 (page 11)
# Scraped 20 rows from 2001-06-02–2001-08-01 (page 12)
# Scraped 20 rows from 2001-06-02–2001-08-01 (page 13)
# Scraped 20 rows from 2001-06-02–2001-08-01 (page 14)
# Scraped 20 rows from 2001-06-02–2001-08-01 (page 15)
# Scraped 20 rows from 2001-06-02–2001-08-01 (page 16)
# Scraped 20 rows from 2001-06-02–2001-08-01 (page 17)
# Scraped 20 rows from 2001-06-02–2001-08-01 (page 18)
# Scraped 20 rows from 2001-06-02–2001-08-01 (page 19)
# Scraped 20 rows from 2001-06-02–2001-08-01 (page 20)
# Scraped 20 rows from 2001-06-02–2001-08-01 (page 21)
# Scraped 20 rows from 2001-06-02–2001-08-01 (page 22)
# Scraped 20 rows from 2001-06-02–2001-08-01 (page 23)
# Scraped 20 rows from 2001-06-02–2001-08-01 (page 24)
# Scraped 20 rows from 2001-06-02–2001-08-01 (page 25)
# Scraped 20 rows from 2001-06-02–2001-08-01 (page 26)
# Scraped 20 rows from 2001-06-02–2001-08-01 (page 27)
# Scraped 20 rows from 2001-06-02–2001-08-01 (page 28)
# Scraped 20 rows from 2001-06-02–2001-08-01 (page 29)
# Scraped 20 rows from 2001-06-02–2001-08-01 (page 30)
# Scraped 20 rows from 2001-06-02–2001-08-01 (page 31)
# Scraped 20 rows from 2001-06-02–2001-08-01 (page 32)
# Scraped 20 rows from 2001-06-02–2001-08-01 (page 33)
# Scraped 20 rows from 2001-06-02–2001-08-01 (page 34)
# Scraped 20 rows from 2001-06-02–2001-08-01 (page 35)
# Scraped 20 rows from 2001-06-02–2001-08-01 (page 36)
# Scraped 20 rows from 2001-06-02–2001-08-01 (page 37)
# Scraped 20 rows from 2001-06-02–2001-08-01 (page 38)
# Scraped 20 rows from 2001-06-02–2001-08-01 (page 39)
# Scraped 20 rows from 2001-06-02–2001-08-01 (page 40)
# Scraped 20 rows from 2001-06-02–2001-08-01 (page 41)
# Scraped 20 rows from 2001-06-02–2001-08-01 (page 42)
# Scraped 20 rows from 2001-06-02–2001-08-01 (page 43)
# Scraped 18 rows from 2001-06-02–2001-08-01 (page 44)
# Scraped 0 rows from 2001-06-02–2001-08-01 (page 45)
# Quarter 2001-06-02_2001-08-01 appended to global dataset.
#
# Processing 2001-08-02 to 2001-10-01...
# Scraped 20 rows from 2001-08-02–2001-10-01 (page 1)
# Scraped 20 rows from 2001-08-02–2001-10-01 (page 2)
# Scraped 20 rows from 2001-08-02–2001-10-01 (page 3)
# Scraped 20 rows from 2001-08-02–2001-10-01 (page 4)
# Scraped 20 rows from 2001-08-02–2001-10-01 (page 5)
# Scraped 20 rows from 2001-08-02–2001-10-01 (page 6)
# Scraped 20 rows from 2001-08-02–2001-10-01 (page 7)
# Scraped 20 rows from 2001-08-02–2001-10-01 (page 8)
# Scraped 20 rows from 2001-08-02–2001-10-01 (page 9)
# Scraped 20 rows from 2001-08-02–2001-10-01 (page 10)
# Scraped 20 rows from 2001-08-02–2001-10-01 (page 11)
# Scraped 20 rows from 2001-08-02–2001-10-01 (page 12)
# Scraped 20 rows from 2001-08-02–2001-10-01 (page 13)
# Scraped 20 rows from 2001-08-02–2001-10-01 (page 14)
# Scraped 20 rows from 2001-08-02–2001-10-01 (page 15)
# Scraped 20 rows from 2001-08-02–2001-10-01 (page 16)
# Scraped 20 rows from 2001-08-02–2001-10-01 (page 17)
# Scraped 20 rows from 2001-08-02–2001-10-01 (page 18)
# Scraped 20 rows from 2001-08-02–2001-10-01 (page 19)
# Scraped 20 rows from 2001-08-02–2001-10-01 (page 20)
# Scraped 20 rows from 2001-08-02–2001-10-01 (page 21)
# Scraped 20 rows from 2001-08-02–2001-10-01 (page 22)
# Scraped 20 rows from 2001-08-02–2001-10-01 (page 23)
# Scraped 20 rows from 2001-08-02–2001-10-01 (page 24)
# Scraped 20 rows from 2001-08-02–2001-10-01 (page 25)
# Scraped 20 rows from 2001-08-02–2001-10-01 (page 26)
# Scraped 20 rows from 2001-08-02–2001-10-01 (page 27)
# Scraped 20 rows from 2001-08-02–2001-10-01 (page 28)
# Scraped 20 rows from 2001-08-02–2001-10-01 (page 29)
# Scraped 20 rows from 2001-08-02–2001-10-01 (page 30)
# Scraped 20 rows from 2001-08-02–2001-10-01 (page 31)
# Scraped 20 rows from 2001-08-02–2001-10-01 (page 32)
# Scraped 20 rows from 2001-08-02–2001-10-01 (page 33)
# Scraped 20 rows from 2001-08-02–2001-10-01 (page 34)
# Scraped 20 rows from 2001-08-02–2001-10-01 (page 35)
# Scraped 20 rows from 2001-08-02–2001-10-01 (page 36)
# Scraped 20 rows from 2001-08-02–2001-10-01 (page 37)
# Scraped 20 rows from 2001-08-02–2001-10-01 (page 38)
# Scraped 20 rows from 2001-08-02–2001-10-01 (page 39)
# Scraped 20 rows from 2001-08-02–2001-10-01 (page 40)
# Scraped 20 rows from 2001-08-02–2001-10-01 (page 41)
# Scraped 20 rows from 2001-08-02–2001-10-01 (page 42)
# Scraped 20 rows from 2001-08-02–2001-10-01 (page 43)
# Scraped 20 rows from 2001-08-02–2001-10-01 (page 44)
# Scraped 1 rows from 2001-08-02–2001-10-01 (page 45)
# Scraped 0 rows from 2001-08-02–2001-10-01 (page 46)
# Quarter 2001-08-02_2001-10-01 appended to global dataset.
#
# Processing 2001-10-02 to 2001-12-01...
# Scraped 20 rows from 2001-10-02–2001-12-01 (page 1)
# Scraped 20 rows from 2001-10-02–2001-12-01 (page 2)
# Scraped 20 rows from 2001-10-02–2001-12-01 (page 3)
# Scraped 20 rows from 2001-10-02–2001-12-01 (page 4)
# Scraped 20 rows from 2001-10-02–2001-12-01 (page 5)
# Scraped 20 rows from 2001-10-02–2001-12-01 (page 6)
# Scraped 20 rows from 2001-10-02–2001-12-01 (page 7)
# Scraped 20 rows from 2001-10-02–2001-12-01 (page 8)
# Scraped 20 rows from 2001-10-02–2001-12-01 (page 9)
# Scraped 20 rows from 2001-10-02–2001-12-01 (page 10)
# Scraped 20 rows from 2001-10-02–2001-12-01 (page 11)
# Scraped 20 rows from 2001-10-02–2001-12-01 (page 12)
# Scraped 20 rows from 2001-10-02–2001-12-01 (page 13)
# Scraped 20 rows from 2001-10-02–2001-12-01 (page 14)
# Scraped 20 rows from 2001-10-02–2001-12-01 (page 15)
# Scraped 20 rows from 2001-10-02–2001-12-01 (page 16)
# Scraped 20 rows from 2001-10-02–2001-12-01 (page 17)
# Scraped 20 rows from 2001-10-02–2001-12-01 (page 18)
# Scraped 20 rows from 2001-10-02–2001-12-01 (page 19)
# Scraped 20 rows from 2001-10-02–2001-12-01 (page 20)
# Scraped 20 rows from 2001-10-02–2001-12-01 (page 21)
# Scraped 20 rows from 2001-10-02–2001-12-01 (page 22)
# Scraped 20 rows from 2001-10-02–2001-12-01 (page 23)
# Scraped 20 rows from 2001-10-02–2001-12-01 (page 24)
# Scraped 20 rows from 2001-10-02–2001-12-01 (page 25)
# Scraped 20 rows from 2001-10-02–2001-12-01 (page 26)
# Scraped 20 rows from 2001-10-02–2001-12-01 (page 27)
# Scraped 17 rows from 2001-10-02–2001-12-01 (page 28)
# Scraped 0 rows from 2001-10-02–2001-12-01 (page 29)
# Quarter 2001-10-02_2001-12-01 appended to global dataset.
#
# Processing 2001-12-02 to 2002-01-31...
# Scraped 20 rows from 2001-12-02–2002-01-31 (page 1)
# Scraped 20 rows from 2001-12-02–2002-01-31 (page 2)
# Scraped 20 rows from 2001-12-02–2002-01-31 (page 3)
# Scraped 20 rows from 2001-12-02–2002-01-31 (page 4)
# Scraped 20 rows from 2001-12-02–2002-01-31 (page 5)
# Scraped 20 rows from 2001-12-02–2002-01-31 (page 6)
# Scraped 20 rows from 2001-12-02–2002-01-31 (page 7)
# Scraped 20 rows from 2001-12-02–2002-01-31 (page 8)
# Scraped 20 rows from 2001-12-02–2002-01-31 (page 9)
# Scraped 20 rows from 2001-12-02–2002-01-31 (page 10)
# Scraped 20 rows from 2001-12-02–2002-01-31 (page 11)
# Scraped 20 rows from 2001-12-02–2002-01-31 (page 12)
# Scraped 20 rows from 2001-12-02–2002-01-31 (page 13)
# Scraped 20 rows from 2001-12-02–2002-01-31 (page 14)
# Scraped 20 rows from 2001-12-02–2002-01-31 (page 15)
# Scraped 20 rows from 2001-12-02–2002-01-31 (page 16)
# Scraped 20 rows from 2001-12-02–2002-01-31 (page 17)
# Scraped 20 rows from 2001-12-02–2002-01-31 (page 18)
# Scraped 20 rows from 2001-12-02–2002-01-31 (page 19)
# Scraped 20 rows from 2001-12-02–2002-01-31 (page 20)
# Scraped 20 rows from 2001-12-02–2002-01-31 (page 21)
# Scraped 20 rows from 2001-12-02–2002-01-31 (page 22)
# Scraped 20 rows from 2001-12-02–2002-01-31 (page 23)
# Scraped 20 rows from 2001-12-02–2002-01-31 (page 24)
# Scraped 20 rows from 2001-12-02–2002-01-31 (page 25)
# Scraped 20 rows from 2001-12-02–2002-01-31 (page 26)
# Scraped 13 rows from 2001-12-02–2002-01-31 (page 27)
# Scraped 0 rows from 2001-12-02–2002-01-31 (page 28)
# Quarter 2001-12-02_2002-01-31 appended to global dataset.
#
# Processing 2002-02-01 to 2002-04-02...
# Scraped 20 rows from 2002-02-01–2002-04-02 (page 1)
# Scraped 20 rows from 2002-02-01–2002-04-02 (page 2)
# Scraped 20 rows from 2002-02-01–2002-04-02 (page 3)
# Scraped 20 rows from 2002-02-01–2002-04-02 (page 4)
# Scraped 20 rows from 2002-02-01–2002-04-02 (page 5)
# Scraped 20 rows from 2002-02-01–2002-04-02 (page 6)
# Scraped 20 rows from 2002-02-01–2002-04-02 (page 7)
# Scraped 20 rows from 2002-02-01–2002-04-02 (page 8)
# Scraped 20 rows from 2002-02-01–2002-04-02 (page 9)
# Scraped 20 rows from 2002-02-01–2002-04-02 (page 10)
# Scraped 20 rows from 2002-02-01–2002-04-02 (page 11)
# Scraped 20 rows from 2002-02-01–2002-04-02 (page 12)
# Scraped 20 rows from 2002-02-01–2002-04-02 (page 13)
# Scraped 20 rows from 2002-02-01–2002-04-02 (page 14)
# Scraped 20 rows from 2002-02-01–2002-04-02 (page 15)
# Scraped 20 rows from 2002-02-01–2002-04-02 (page 16)
# Scraped 20 rows from 2002-02-01–2002-04-02 (page 17)
# Scraped 20 rows from 2002-02-01–2002-04-02 (page 18)
# Scraped 20 rows from 2002-02-01–2002-04-02 (page 19)
# Scraped 20 rows from 2002-02-01–2002-04-02 (page 20)
# Scraped 20 rows from 2002-02-01–2002-04-02 (page 21)
# Scraped 20 rows from 2002-02-01–2002-04-02 (page 22)
# Scraped 20 rows from 2002-02-01–2002-04-02 (page 23)
# Scraped 20 rows from 2002-02-01–2002-04-02 (page 24)
# Scraped 20 rows from 2002-02-01–2002-04-02 (page 25)
# Scraped 20 rows from 2002-02-01–2002-04-02 (page 26)
# Scraped 20 rows from 2002-02-01–2002-04-02 (page 27)
# Scraped 20 rows from 2002-02-01–2002-04-02 (page 28)
# Scraped 20 rows from 2002-02-01–2002-04-02 (page 29)
# Scraped 16 rows from 2002-02-01–2002-04-02 (page 30)
# Scraped 0 rows from 2002-02-01–2002-04-02 (page 31)
# Quarter 2002-02-01_2002-04-02 appended to global dataset.
#
# Processing 2002-04-03 to 2002-06-02...
# Scraped 20 rows from 2002-04-03–2002-06-02 (page 1)
# Scraped 20 rows from 2002-04-03–2002-06-02 (page 2)
# Scraped 20 rows from 2002-04-03–2002-06-02 (page 3)
# Scraped 20 rows from 2002-04-03–2002-06-02 (page 4)
# Scraped 20 rows from 2002-04-03–2002-06-02 (page 5)
# Scraped 20 rows from 2002-04-03–2002-06-02 (page 6)
# Scraped 20 rows from 2002-04-03–2002-06-02 (page 7)
# Scraped 20 rows from 2002-04-03–2002-06-02 (page 8)
# Scraped 20 rows from 2002-04-03–2002-06-02 (page 9)
# Scraped 20 rows from 2002-04-03–2002-06-02 (page 10)
# Scraped 20 rows from 2002-04-03–2002-06-02 (page 11)
# Scraped 20 rows from 2002-04-03–2002-06-02 (page 12)
# Scraped 20 rows from 2002-04-03–2002-06-02 (page 13)
# Scraped 20 rows from 2002-04-03–2002-06-02 (page 14)
# Scraped 20 rows from 2002-04-03–2002-06-02 (page 15)
# Scraped 20 rows from 2002-04-03–2002-06-02 (page 16)
# Scraped 20 rows from 2002-04-03–2002-06-02 (page 17)
# Scraped 20 rows from 2002-04-03–2002-06-02 (page 18)
# Scraped 20 rows from 2002-04-03–2002-06-02 (page 19)
# Scraped 20 rows from 2002-04-03–2002-06-02 (page 20)
# Scraped 20 rows from 2002-04-03–2002-06-02 (page 21)
# Scraped 20 rows from 2002-04-03–2002-06-02 (page 22)
# Scraped 20 rows from 2002-04-03–2002-06-02 (page 23)
# Scraped 20 rows from 2002-04-03–2002-06-02 (page 24)
# Scraped 20 rows from 2002-04-03–2002-06-02 (page 25)
# Scraped 20 rows from 2002-04-03–2002-06-02 (page 26)
# Scraped 20 rows from 2002-04-03–2002-06-02 (page 27)
# Scraped 20 rows from 2002-04-03–2002-06-02 (page 28)
# Scraped 20 rows from 2002-04-03–2002-06-02 (page 29)
# Scraped 6 rows from 2002-04-03–2002-06-02 (page 30)
# Scraped 0 rows from 2002-04-03–2002-06-02 (page 31)
# Quarter 2002-04-03_2002-06-02 appended to global dataset.
#
# Processing 2002-06-03 to 2002-08-02...
# Scraped 20 rows from 2002-06-03–2002-08-02 (page 1)
# Scraped 20 rows from 2002-06-03–2002-08-02 (page 2)
# Scraped 20 rows from 2002-06-03–2002-08-02 (page 3)
# Scraped 20 rows from 2002-06-03–2002-08-02 (page 4)
# Scraped 20 rows from 2002-06-03–2002-08-02 (page 5)
# Scraped 20 rows from 2002-06-03–2002-08-02 (page 6)
# Scraped 20 rows from 2002-06-03–2002-08-02 (page 7)
# Scraped 20 rows from 2002-06-03–2002-08-02 (page 8)
# Scraped 20 rows from 2002-06-03–2002-08-02 (page 9)
# Scraped 20 rows from 2002-06-03–2002-08-02 (page 10)
# Scraped 20 rows from 2002-06-03–2002-08-02 (page 11)
# Scraped 20 rows from 2002-06-03–2002-08-02 (page 12)
# Scraped 20 rows from 2002-06-03–2002-08-02 (page 13)
# Scraped 20 rows from 2002-06-03–2002-08-02 (page 14)
# Scraped 20 rows from 2002-06-03–2002-08-02 (page 15)
# Scraped 20 rows from 2002-06-03–2002-08-02 (page 16)
# Scraped 20 rows from 2002-06-03–2002-08-02 (page 17)
# Scraped 20 rows from 2002-06-03–2002-08-02 (page 18)
# Scraped 20 rows from 2002-06-03–2002-08-02 (page 19)
# Scraped 20 rows from 2002-06-03–2002-08-02 (page 20)
# Scraped 20 rows from 2002-06-03–2002-08-02 (page 21)
# Scraped 20 rows from 2002-06-03–2002-08-02 (page 22)
# Scraped 20 rows from 2002-06-03–2002-08-02 (page 23)
# Scraped 20 rows from 2002-06-03–2002-08-02 (page 24)
# Scraped 20 rows from 2002-06-03–2002-08-02 (page 25)
# Scraped 20 rows from 2002-06-03–2002-08-02 (page 26)
# Scraped 20 rows from 2002-06-03–2002-08-02 (page 27)
# Scraped 20 rows from 2002-06-03–2002-08-02 (page 28)
# Scraped 20 rows from 2002-06-03–2002-08-02 (page 29)
# Scraped 20 rows from 2002-06-03–2002-08-02 (page 30)
# Scraped 20 rows from 2002-06-03–2002-08-02 (page 31)
# Scraped 19 rows from 2002-06-03–2002-08-02 (page 32)
# Scraped 0 rows from 2002-06-03–2002-08-02 (page 33)
# Quarter 2002-06-03_2002-08-02 appended to global dataset.
#
# Processing 2002-08-03 to 2002-10-02...
# Scraped 20 rows from 2002-08-03–2002-10-02 (page 1)
# Scraped 20 rows from 2002-08-03–2002-10-02 (page 2)
# Scraped 20 rows from 2002-08-03–2002-10-02 (page 3)
# Scraped 20 rows from 2002-08-03–2002-10-02 (page 4)
# Scraped 20 rows from 2002-08-03–2002-10-02 (page 5)
# Scraped 20 rows from 2002-08-03–2002-10-02 (page 6)
# Scraped 20 rows from 2002-08-03–2002-10-02 (page 7)
# Scraped 20 rows from 2002-08-03–2002-10-02 (page 8)
# Scraped 20 rows from 2002-08-03–2002-10-02 (page 9)
# Scraped 20 rows from 2002-08-03–2002-10-02 (page 10)
# Scraped 20 rows from 2002-08-03–2002-10-02 (page 11)
# Scraped 20 rows from 2002-08-03–2002-10-02 (page 12)
# Scraped 20 rows from 2002-08-03–2002-10-02 (page 13)
# Scraped 20 rows from 2002-08-03–2002-10-02 (page 14)
# Scraped 20 rows from 2002-08-03–2002-10-02 (page 15)
# Scraped 20 rows from 2002-08-03–2002-10-02 (page 16)
# Scraped 20 rows from 2002-08-03–2002-10-02 (page 17)
# Scraped 20 rows from 2002-08-03–2002-10-02 (page 18)
# Scraped 20 rows from 2002-08-03–2002-10-02 (page 19)
# Scraped 20 rows from 2002-08-03–2002-10-02 (page 20)
# Scraped 20 rows from 2002-08-03–2002-10-02 (page 21)
# Scraped 20 rows from 2002-08-03–2002-10-02 (page 22)
# Scraped 20 rows from 2002-08-03–2002-10-02 (page 23)
# Scraped 20 rows from 2002-08-03–2002-10-02 (page 24)
# Scraped 20 rows from 2002-08-03–2002-10-02 (page 25)
# Scraped 20 rows from 2002-08-03–2002-10-02 (page 26)
# Scraped 20 rows from 2002-08-03–2002-10-02 (page 27)
# Scraped 20 rows from 2002-08-03–2002-10-02 (page 28)
# Scraped 20 rows from 2002-08-03–2002-10-02 (page 29)
# Scraped 20 rows from 2002-08-03–2002-10-02 (page 30)
# Scraped 20 rows from 2002-08-03–2002-10-02 (page 31)
# Scraped 10 rows from 2002-08-03–2002-10-02 (page 32)
# Scraped 0 rows from 2002-08-03–2002-10-02 (page 33)
# Quarter 2002-08-03_2002-10-02 appended to global dataset.
#
# Processing 2002-10-03 to 2002-12-02...
# Scraped 20 rows from 2002-10-03–2002-12-02 (page 1)
# Scraped 20 rows from 2002-10-03–2002-12-02 (page 2)
# Scraped 20 rows from 2002-10-03–2002-12-02 (page 3)
# Scraped 20 rows from 2002-10-03–2002-12-02 (page 4)
# Scraped 20 rows from 2002-10-03–2002-12-02 (page 5)
# Scraped 20 rows from 2002-10-03–2002-12-02 (page 6)
# Scraped 20 rows from 2002-10-03–2002-12-02 (page 7)
# Scraped 20 rows from 2002-10-03–2002-12-02 (page 8)
# Scraped 20 rows from 2002-10-03–2002-12-02 (page 9)
# Scraped 20 rows from 2002-10-03–2002-12-02 (page 10)
# Scraped 20 rows from 2002-10-03–2002-12-02 (page 11)
# Scraped 20 rows from 2002-10-03–2002-12-02 (page 12)
# Scraped 20 rows from 2002-10-03–2002-12-02 (page 13)
# Scraped 20 rows from 2002-10-03–2002-12-02 (page 14)
# Scraped 20 rows from 2002-10-03–2002-12-02 (page 15)
# Scraped 20 rows from 2002-10-03–2002-12-02 (page 16)
# Scraped 20 rows from 2002-10-03–2002-12-02 (page 17)
# Scraped 20 rows from 2002-10-03–2002-12-02 (page 18)
# Scraped 20 rows from 2002-10-03–2002-12-02 (page 19)
# Scraped 20 rows from 2002-10-03–2002-12-02 (page 20)
# Scraped 20 rows from 2002-10-03–2002-12-02 (page 21)
# Scraped 20 rows from 2002-10-03–2002-12-02 (page 22)
# Scraped 20 rows from 2002-10-03–2002-12-02 (page 23)
# Scraped 20 rows from 2002-10-03–2002-12-02 (page 24)
# Scraped 20 rows from 2002-10-03–2002-12-02 (page 25)
# Scraped 20 rows from 2002-10-03–2002-12-02 (page 26)
# Scraped 20 rows from 2002-10-03–2002-12-02 (page 27)
# Scraped 20 rows from 2002-10-03–2002-12-02 (page 28)
# Scraped 20 rows from 2002-10-03–2002-12-02 (page 29)
# Scraped 20 rows from 2002-10-03–2002-12-02 (page 30)
# Scraped 9 rows from 2002-10-03–2002-12-02 (page 31)
# Scraped 0 rows from 2002-10-03–2002-12-02 (page 32)
# Quarter 2002-10-03_2002-12-02 appended to global dataset.
#
# Processing 2002-12-03 to 2003-02-01...
# Scraped 20 rows from 2002-12-03–2003-02-01 (page 1)
# Scraped 20 rows from 2002-12-03–2003-02-01 (page 2)
# Scraped 20 rows from 2002-12-03–2003-02-01 (page 3)
# Scraped 20 rows from 2002-12-03–2003-02-01 (page 4)
# Scraped 20 rows from 2002-12-03–2003-02-01 (page 5)
# Scraped 20 rows from 2002-12-03–2003-02-01 (page 6)
# Scraped 20 rows from 2002-12-03–2003-02-01 (page 7)
# Scraped 20 rows from 2002-12-03–2003-02-01 (page 8)
# Scraped 20 rows from 2002-12-03–2003-02-01 (page 9)
# Scraped 20 rows from 2002-12-03–2003-02-01 (page 10)
# Scraped 20 rows from 2002-12-03–2003-02-01 (page 11)
# Scraped 20 rows from 2002-12-03–2003-02-01 (page 12)
# Scraped 20 rows from 2002-12-03–2003-02-01 (page 13)
# Scraped 20 rows from 2002-12-03–2003-02-01 (page 14)
# Scraped 20 rows from 2002-12-03–2003-02-01 (page 15)
# Scraped 20 rows from 2002-12-03–2003-02-01 (page 16)
# Scraped 20 rows from 2002-12-03–2003-02-01 (page 17)
# Scraped 20 rows from 2002-12-03–2003-02-01 (page 18)
# Scraped 20 rows from 2002-12-03–2003-02-01 (page 19)
# Scraped 20 rows from 2002-12-03–2003-02-01 (page 20)
# Scraped 20 rows from 2002-12-03–2003-02-01 (page 21)
# Scraped 20 rows from 2002-12-03–2003-02-01 (page 22)
# Scraped 20 rows from 2002-12-03–2003-02-01 (page 23)
# Scraped 20 rows from 2002-12-03–2003-02-01 (page 24)
# Scraped 13 rows from 2002-12-03–2003-02-01 (page 25)
# Scraped 0 rows from 2002-12-03–2003-02-01 (page 26)
# Quarter 2002-12-03_2003-02-01 appended to global dataset.
#
# Processing 2003-02-02 to 2003-04-03...
# Scraped 20 rows from 2003-02-02–2003-04-03 (page 1)
# Scraped 20 rows from 2003-02-02–2003-04-03 (page 2)
# Scraped 20 rows from 2003-02-02–2003-04-03 (page 3)
# Scraped 20 rows from 2003-02-02–2003-04-03 (page 4)
# Scraped 20 rows from 2003-02-02–2003-04-03 (page 5)
# Scraped 20 rows from 2003-02-02–2003-04-03 (page 6)
# Scraped 20 rows from 2003-02-02–2003-04-03 (page 7)
# Scraped 20 rows from 2003-02-02–2003-04-03 (page 8)
# Scraped 20 rows from 2003-02-02–2003-04-03 (page 9)
# Scraped 20 rows from 2003-02-02–2003-04-03 (page 10)
# Scraped 20 rows from 2003-02-02–2003-04-03 (page 11)
# Scraped 20 rows from 2003-02-02–2003-04-03 (page 12)
# Scraped 20 rows from 2003-02-02–2003-04-03 (page 13)
# Scraped 20 rows from 2003-02-02–2003-04-03 (page 14)
# Scraped 20 rows from 2003-02-02–2003-04-03 (page 15)
# Scraped 20 rows from 2003-02-02–2003-04-03 (page 16)
# Scraped 20 rows from 2003-02-02–2003-04-03 (page 17)
# Scraped 20 rows from 2003-02-02–2003-04-03 (page 18)
# Scraped 20 rows from 2003-02-02–2003-04-03 (page 19)
# Scraped 20 rows from 2003-02-02–2003-04-03 (page 20)
# Scraped 20 rows from 2003-02-02–2003-04-03 (page 21)
# Scraped 20 rows from 2003-02-02–2003-04-03 (page 22)
# Scraped 20 rows from 2003-02-02–2003-04-03 (page 23)
# Scraped 20 rows from 2003-02-02–2003-04-03 (page 24)
# Scraped 20 rows from 2003-02-02–2003-04-03 (page 25)
# Scraped 20 rows from 2003-02-02–2003-04-03 (page 26)
# Scraped 20 rows from 2003-02-02–2003-04-03 (page 27)
# Scraped 20 rows from 2003-02-02–2003-04-03 (page 28)
# Scraped 20 rows from 2003-02-02–2003-04-03 (page 29)
# Scraped 20 rows from 2003-02-02–2003-04-03 (page 30)
# Scraped 20 rows from 2003-02-02–2003-04-03 (page 31)
# Scraped 20 rows from 2003-02-02–2003-04-03 (page 32)
# Scraped 17 rows from 2003-02-02–2003-04-03 (page 33)
# Scraped 0 rows from 2003-02-02–2003-04-03 (page 34)
# Quarter 2003-02-02_2003-04-03 appended to global dataset.
#
# Processing 2003-04-04 to 2003-06-03...
# Scraped 20 rows from 2003-04-04–2003-06-03 (page 1)
# Scraped 20 rows from 2003-04-04–2003-06-03 (page 2)
# Scraped 20 rows from 2003-04-04–2003-06-03 (page 3)
# Scraped 20 rows from 2003-04-04–2003-06-03 (page 4)
# Scraped 20 rows from 2003-04-04–2003-06-03 (page 5)
# Scraped 20 rows from 2003-04-04–2003-06-03 (page 6)
# Scraped 20 rows from 2003-04-04–2003-06-03 (page 7)
# Scraped 20 rows from 2003-04-04–2003-06-03 (page 8)
# Scraped 20 rows from 2003-04-04–2003-06-03 (page 9)
# Scraped 20 rows from 2003-04-04–2003-06-03 (page 10)
# Scraped 20 rows from 2003-04-04–2003-06-03 (page 11)
# Scraped 20 rows from 2003-04-04–2003-06-03 (page 12)
# Scraped 20 rows from 2003-04-04–2003-06-03 (page 13)
# Scraped 20 rows from 2003-04-04–2003-06-03 (page 14)
# Scraped 20 rows from 2003-04-04–2003-06-03 (page 15)
# Scraped 20 rows from 2003-04-04–2003-06-03 (page 16)
# Scraped 20 rows from 2003-04-04–2003-06-03 (page 17)
# Scraped 20 rows from 2003-04-04–2003-06-03 (page 18)
# Scraped 20 rows from 2003-04-04–2003-06-03 (page 19)
# Scraped 20 rows from 2003-04-04–2003-06-03 (page 20)
# Scraped 20 rows from 2003-04-04–2003-06-03 (page 21)
# Scraped 20 rows from 2003-04-04–2003-06-03 (page 22)
# Scraped 20 rows from 2003-04-04–2003-06-03 (page 23)
# Scraped 20 rows from 2003-04-04–2003-06-03 (page 24)
# Scraped 20 rows from 2003-04-04–2003-06-03 (page 25)
# Scraped 20 rows from 2003-04-04–2003-06-03 (page 26)
# Scraped 20 rows from 2003-04-04–2003-06-03 (page 27)
# Scraped 20 rows from 2003-04-04–2003-06-03 (page 28)
# Scraped 20 rows from 2003-04-04–2003-06-03 (page 29)
# Scraped 19 rows from 2003-04-04–2003-06-03 (page 30)
# Scraped 0 rows from 2003-04-04–2003-06-03 (page 31)
# Quarter 2003-04-04_2003-06-03 appended to global dataset.
#
# Processing 2003-06-04 to 2003-08-03...
# Scraped 20 rows from 2003-06-04–2003-08-03 (page 1)
# Scraped 20 rows from 2003-06-04–2003-08-03 (page 2)
# Scraped 20 rows from 2003-06-04–2003-08-03 (page 3)
# Scraped 20 rows from 2003-06-04–2003-08-03 (page 4)
# Scraped 20 rows from 2003-06-04–2003-08-03 (page 5)
# Scraped 20 rows from 2003-06-04–2003-08-03 (page 6)
# Scraped 20 rows from 2003-06-04–2003-08-03 (page 7)
# Scraped 20 rows from 2003-06-04–2003-08-03 (page 8)
# Scraped 20 rows from 2003-06-04–2003-08-03 (page 9)
# Scraped 20 rows from 2003-06-04–2003-08-03 (page 10)
# Scraped 20 rows from 2003-06-04–2003-08-03 (page 11)
# Scraped 20 rows from 2003-06-04–2003-08-03 (page 12)
# Scraped 20 rows from 2003-06-04–2003-08-03 (page 13)
# Scraped 20 rows from 2003-06-04–2003-08-03 (page 14)
# Scraped 20 rows from 2003-06-04–2003-08-03 (page 15)
# Scraped 20 rows from 2003-06-04–2003-08-03 (page 16)
# Scraped 20 rows from 2003-06-04–2003-08-03 (page 17)
# Scraped 20 rows from 2003-06-04–2003-08-03 (page 18)
# Scraped 20 rows from 2003-06-04–2003-08-03 (page 19)
# Scraped 20 rows from 2003-06-04–2003-08-03 (page 20)
# Scraped 20 rows from 2003-06-04–2003-08-03 (page 21)
# Scraped 20 rows from 2003-06-04–2003-08-03 (page 22)
# Scraped 20 rows from 2003-06-04–2003-08-03 (page 23)
# Scraped 20 rows from 2003-06-04–2003-08-03 (page 24)
# Scraped 20 rows from 2003-06-04–2003-08-03 (page 25)
# Scraped 20 rows from 2003-06-04–2003-08-03 (page 26)
# Scraped 20 rows from 2003-06-04–2003-08-03 (page 27)
# Scraped 18 rows from 2003-06-04–2003-08-03 (page 28)
# Scraped 0 rows from 2003-06-04–2003-08-03 (page 29)
# Quarter 2003-06-04_2003-08-03 appended to global dataset.
#
# Processing 2003-08-04 to 2003-10-03...
# Scraped 20 rows from 2003-08-04–2003-10-03 (page 1)
# Scraped 20 rows from 2003-08-04–2003-10-03 (page 2)
# Scraped 20 rows from 2003-08-04–2003-10-03 (page 3)
# Scraped 20 rows from 2003-08-04–2003-10-03 (page 4)
# Scraped 20 rows from 2003-08-04–2003-10-03 (page 5)
# Scraped 20 rows from 2003-08-04–2003-10-03 (page 6)
# Scraped 20 rows from 2003-08-04–2003-10-03 (page 7)
# Scraped 20 rows from 2003-08-04–2003-10-03 (page 8)
# Scraped 20 rows from 2003-08-04–2003-10-03 (page 9)
# Scraped 20 rows from 2003-08-04–2003-10-03 (page 10)
# Scraped 20 rows from 2003-08-04–2003-10-03 (page 11)
# Scraped 20 rows from 2003-08-04–2003-10-03 (page 12)
# Scraped 20 rows from 2003-08-04–2003-10-03 (page 13)
# Scraped 20 rows from 2003-08-04–2003-10-03 (page 14)
# Scraped 20 rows from 2003-08-04–2003-10-03 (page 15)
# Scraped 20 rows from 2003-08-04–2003-10-03 (page 16)
# Scraped 20 rows from 2003-08-04–2003-10-03 (page 17)
# Scraped 20 rows from 2003-08-04–2003-10-03 (page 18)
# Scraped 20 rows from 2003-08-04–2003-10-03 (page 19)
# Scraped 20 rows from 2003-08-04–2003-10-03 (page 20)
# Scraped 20 rows from 2003-08-04–2003-10-03 (page 21)
# Scraped 20 rows from 2003-08-04–2003-10-03 (page 22)
# Scraped 20 rows from 2003-08-04–2003-10-03 (page 23)
# Scraped 20 rows from 2003-08-04–2003-10-03 (page 24)
# Scraped 20 rows from 2003-08-04–2003-10-03 (page 25)
# Scraped 20 rows from 2003-08-04–2003-10-03 (page 26)
# Scraped 17 rows from 2003-08-04–2003-10-03 (page 27)
# Scraped 0 rows from 2003-08-04–2003-10-03 (page 28)
# Quarter 2003-08-04_2003-10-03 appended to global dataset.
#
# Processing 2003-10-04 to 2003-12-03...
# Scraped 20 rows from 2003-10-04–2003-12-03 (page 1)
# Scraped 20 rows from 2003-10-04–2003-12-03 (page 2)
# Scraped 20 rows from 2003-10-04–2003-12-03 (page 3)
# Scraped 20 rows from 2003-10-04–2003-12-03 (page 4)
# Scraped 20 rows from 2003-10-04–2003-12-03 (page 5)
# Scraped 20 rows from 2003-10-04–2003-12-03 (page 6)
# Scraped 20 rows from 2003-10-04–2003-12-03 (page 7)
# Scraped 20 rows from 2003-10-04–2003-12-03 (page 8)
# Scraped 20 rows from 2003-10-04–2003-12-03 (page 9)
# Scraped 20 rows from 2003-10-04–2003-12-03 (page 10)
# Scraped 20 rows from 2003-10-04–2003-12-03 (page 11)
# Scraped 20 rows from 2003-10-04–2003-12-03 (page 12)
# Scraped 20 rows from 2003-10-04–2003-12-03 (page 13)
# Scraped 20 rows from 2003-10-04–2003-12-03 (page 14)
# Scraped 20 rows from 2003-10-04–2003-12-03 (page 15)
# Scraped 20 rows from 2003-10-04–2003-12-03 (page 16)
# Scraped 20 rows from 2003-10-04–2003-12-03 (page 17)
# Scraped 20 rows from 2003-10-04–2003-12-03 (page 18)
# Scraped 20 rows from 2003-10-04–2003-12-03 (page 19)
# Scraped 20 rows from 2003-10-04–2003-12-03 (page 20)
# Scraped 20 rows from 2003-10-04–2003-12-03 (page 21)
# Scraped 20 rows from 2003-10-04–2003-12-03 (page 22)
# Scraped 2 rows from 2003-10-04–2003-12-03 (page 23)
# Scraped 0 rows from 2003-10-04–2003-12-03 (page 24)
# Quarter 2003-10-04_2003-12-03 appended to global dataset.
#
# Processing 2003-12-04 to 2004-02-02...
# Scraped 20 rows from 2003-12-04–2004-02-02 (page 1)
# Scraped 20 rows from 2003-12-04–2004-02-02 (page 2)
# Scraped 20 rows from 2003-12-04–2004-02-02 (page 3)
# Scraped 20 rows from 2003-12-04–2004-02-02 (page 4)
# Scraped 20 rows from 2003-12-04–2004-02-02 (page 5)
# Scraped 20 rows from 2003-12-04–2004-02-02 (page 6)
# Scraped 20 rows from 2003-12-04–2004-02-02 (page 7)
# Scraped 20 rows from 2003-12-04–2004-02-02 (page 8)
# Scraped 20 rows from 2003-12-04–2004-02-02 (page 9)
# Scraped 20 rows from 2003-12-04–2004-02-02 (page 10)
# Scraped 20 rows from 2003-12-04–2004-02-02 (page 11)
# Scraped 20 rows from 2003-12-04–2004-02-02 (page 12)
# Scraped 20 rows from 2003-12-04–2004-02-02 (page 13)
# Scraped 20 rows from 2003-12-04–2004-02-02 (page 14)
# Scraped 20 rows from 2003-12-04–2004-02-02 (page 15)
# Scraped 20 rows from 2003-12-04–2004-02-02 (page 16)
# Scraped 20 rows from 2003-12-04–2004-02-02 (page 17)
# Scraped 11 rows from 2003-12-04–2004-02-02 (page 18)
# Scraped 0 rows from 2003-12-04–2004-02-02 (page 19)
# Quarter 2003-12-04_2004-02-02 appended to global dataset.
#
# Processing 2004-02-03 to 2004-04-03...
# Scraped 20 rows from 2004-02-03–2004-04-03 (page 1)
# Scraped 20 rows from 2004-02-03–2004-04-03 (page 2)
# Scraped 20 rows from 2004-02-03–2004-04-03 (page 3)
# Scraped 20 rows from 2004-02-03–2004-04-03 (page 4)
# ...
# Scraped 20 rows from 2020-06-16–2020-08-15 (page 7)
# Scraped 20 rows from 2020-06-16–2020-08-15 (page 8)
# Scraped 20 rows from 2020-06-16–2020-08-15 (page 9)
# Scraped 20 rows from 2020-06-16–2020-08-15 (page 10)
# Scraped 20 rows from 2020-06-16–2020-08-15 (page 11)
# Scraped 4 rows from 2020-06-16–2020-08-15 (page 12)
# Scraped 0 rows from 2020-06-16–2020-08-15 (page 13)
# Quarter 2020-06-16_2020-08-15 appended to global dataset.
#
# Processing 2020-08-16 to 2020-10-15...
# Scraped 20 rows from 2020-08-16–2020-10-15 (page 1)
# Scraped 20 rows from 2020-08-16–2020-10-15 (page 2)
# Scraped 20 rows from 2020-08-16–2020-10-15 (page 3)
# Scraped 20 rows from 2020-08-16–2020-10-15 (page 4)
# Scraped 20 rows from 2020-08-16–2020-10-15 (page 5)
# Scraped 20 rows from 2020-08-16–2020-10-15 (page 6)
# Scraped 20 rows from 2020-08-16–2020-10-15 (page 7)
# Scraped 20 rows from 2020-08-16–2020-10-15 (page 8)
# Scraped 20 rows from 2020-08-16–2020-10-15 (page 9)
# Scraped 20 rows from 2020-08-16–2020-10-15 (page 10)
# Scraped 20 rows from 2020-08-16–2020-10-15 (page 11)
# Scraped 10 rows from 2020-08-16–2020-10-15 (page 12)
# Scraped 0 rows from 2020-08-16–2020-10-15 (page 13)
# Quarter 2020-08-16_2020-10-15 appended to global dataset.
#
# Processing 2020-10-16 to 2020-12-15...
# Scraped 20 rows from 2020-10-16–2020-12-15 (page 1)
# Scraped 20 rows from 2020-10-16–2020-12-15 (page 2)
# Scraped 20 rows from 2020-10-16–2020-12-15 (page 3)
# Scraped 20 rows from 2020-10-16–2020-12-15 (page 4)
# Scraped 20 rows from 2020-10-16–2020-12-15 (page 5)
# Scraped 20 rows from 2020-10-16–2020-12-15 (page 6)
# Scraped 20 rows from 2020-10-16–2020-12-15 (page 7)
# Scraped 20 rows from 2020-10-16–2020-12-15 (page 8)
# Scraped 20 rows from 2020-10-16–2020-12-15 (page 9)
# Scraped 20 rows from 2020-10-16–2020-12-15 (page 10)
# Scraped 5 rows from 2020-10-16–2020-12-15 (page 11)
# Scraped 0 rows from 2020-10-16–2020-12-15 (page 12)
# Quarter 2020-10-16_2020-12-15 appended to global dataset.
#
# Processing 2020-12-16 to 2021-02-14...
# Scraped 20 rows from 2020-12-16–2021-02-14 (page 1)
# Scraped 20 rows from 2020-12-16–2021-02-14 (page 2)
# Scraped 20 rows from 2020-12-16–2021-02-14 (page 3)
# Scraped 20 rows from 2020-12-16–2021-02-14 (page 4)
# Scraped 20 rows from 2020-12-16–2021-02-14 (page 5)
# Scraped 20 rows from 2020-12-16–2021-02-14 (page 6)
# Scraped 20 rows from 2020-12-16–2021-02-14 (page 7)
# Scraped 20 rows from 2020-12-16–2021-02-14 (page 8)
# Scraped 3 rows from 2020-12-16–2021-02-14 (page 9)
# Scraped 0 rows from 2020-12-16–2021-02-14 (page 10)
# Quarter 2020-12-16_2021-02-14 appended to global dataset.
#
# Processing 2021-02-15 to 2021-04-16...
# Scraped 20 rows from 2021-02-15–2021-04-16 (page 1)
# Scraped 20 rows from 2021-02-15–2021-04-16 (page 2)
# Scraped 20 rows from 2021-02-15–2021-04-16 (page 3)
# Scraped 20 rows from 2021-02-15–2021-04-16 (page 4)
# Scraped 20 rows from 2021-02-15–2021-04-16 (page 5)
# Scraped 20 rows from 2021-02-15–2021-04-16 (page 6)
# Scraped 20 rows from 2021-02-15–2021-04-16 (page 7)
# Scraped 20 rows from 2021-02-15–2021-04-16 (page 8)
# Scraped 20 rows from 2021-02-15–2021-04-16 (page 9)
# Scraped 18 rows from 2021-02-15–2021-04-16 (page 10)
# Scraped 0 rows from 2021-02-15–2021-04-16 (page 11)
# Quarter 2021-02-15_2021-04-16 appended to global dataset.
#
# Processing 2021-04-17 to 2021-06-16...
# Scraped 20 rows from 2021-04-17–2021-06-16 (page 1)
# Scraped 20 rows from 2021-04-17–2021-06-16 (page 2)
# Scraped 20 rows from 2021-04-17–2021-06-16 (page 3)
# Scraped 20 rows from 2021-04-17–2021-06-16 (page 4)
# Scraped 20 rows from 2021-04-17–2021-06-16 (page 5)
# Scraped 20 rows from 2021-04-17–2021-06-16 (page 6)
# Scraped 20 rows from 2021-04-17–2021-06-16 (page 7)
# Scraped 20 rows from 2021-04-17–2021-06-16 (page 8)
# Scraped 20 rows from 2021-04-17–2021-06-16 (page 9)
# Scraped 20 rows from 2021-04-17–2021-06-16 (page 10)
# Scraped 20 rows from 2021-04-17–2021-06-16 (page 11)
# Scraped 20 rows from 2021-04-17–2021-06-16 (page 12)
# Scraped 20 rows from 2021-04-17–2021-06-16 (page 13)
# Scraped 20 rows from 2021-04-17–2021-06-16 (page 14)
# Scraped 20 rows from 2021-04-17–2021-06-16 (page 15)
# Scraped 11 rows from 2021-04-17–2021-06-16 (page 16)
# Scraped 0 rows from 2021-04-17–2021-06-16 (page 17)
# Quarter 2021-04-17_2021-06-16 appended to global dataset.
#
# Processing 2021-06-17 to 2021-08-16...
# Scraped 20 rows from 2021-06-17–2021-08-16 (page 1)
# Scraped 20 rows from 2021-06-17–2021-08-16 (page 2)
# Scraped 20 rows from 2021-06-17–2021-08-16 (page 3)
# Scraped 20 rows from 2021-06-17–2021-08-16 (page 4)
# Scraped 20 rows from 2021-06-17–2021-08-16 (page 5)
# Scraped 20 rows from 2021-06-17–2021-08-16 (page 6)
# Scraped 20 rows from 2021-06-17–2021-08-16 (page 7)
# Scraped 14 rows from 2021-06-17–2021-08-16 (page 8)
# Scraped 0 rows from 2021-06-17–2021-08-16 (page 9)
# Quarter 2021-06-17_2021-08-16 appended to global dataset.
#
# Processing 2021-08-17 to 2021-10-16...
# Scraped 20 rows from 2021-08-17–2021-10-16 (page 1)
# Scraped 20 rows from 2021-08-17–2021-10-16 (page 2)
# Scraped 20 rows from 2021-08-17–2021-10-16 (page 3)
# Scraped 20 rows from 2021-08-17–2021-10-16 (page 4)
# Scraped 20 rows from 2021-08-17–2021-10-16 (page 5)
# Scraped 20 rows from 2021-08-17–2021-10-16 (page 6)
# Scraped 20 rows from 2021-08-17–2021-10-16 (page 7)
# Scraped 18 rows from 2021-08-17–2021-10-16 (page 8)
# Scraped 0 rows from 2021-08-17–2021-10-16 (page 9)
# Quarter 2021-08-17_2021-10-16 appended to global dataset.
#
# Processing 2021-10-17 to 2021-12-16...
# Scraped 20 rows from 2021-10-17–2021-12-16 (page 1)
# Scraped 20 rows from 2021-10-17–2021-12-16 (page 2)
# Scraped 20 rows from 2021-10-17–2021-12-16 (page 3)
# Scraped 20 rows from 2021-10-17–2021-12-16 (page 4)
# Scraped 20 rows from 2021-10-17–2021-12-16 (page 5)
# Scraped 20 rows from 2021-10-17–2021-12-16 (page 6)
# Scraped 14 rows from 2021-10-17–2021-12-16 (page 7)
# Scraped 0 rows from 2021-10-17–2021-12-16 (page 8)
# Quarter 2021-10-17_2021-12-16 appended to global dataset.
#
# Processing 2021-12-17 to 2022-02-15...
# Scraped 20 rows from 2021-12-17–2022-02-15 (page 1)
# Scraped 20 rows from 2021-12-17–2022-02-15 (page 2)
# Scraped 20 rows from 2021-12-17–2022-02-15 (page 3)
# Scraped 20 rows from 2021-12-17–2022-02-15 (page 4)
# Scraped 20 rows from 2021-12-17–2022-02-15 (page 5)
# Scraped 20 rows from 2021-12-17–2022-02-15 (page 6)
# Scraped 20 rows from 2021-12-17–2022-02-15 (page 7)
# Scraped 6 rows from 2021-12-17–2022-02-15 (page 8)
# Scraped 0 rows from 2021-12-17–2022-02-15 (page 9)
# Quarter 2021-12-17_2022-02-15 appended to global dataset.
#
# Processing 2022-02-16 to 2022-04-17...
# Scraped 20 rows from 2022-02-16–2022-04-17 (page 1)
# Scraped 20 rows from 2022-02-16–2022-04-17 (page 2)
# Scraped 20 rows from 2022-02-16–2022-04-17 (page 3)
# Scraped 20 rows from 2022-02-16–2022-04-17 (page 4)
# Scraped 20 rows from 2022-02-16–2022-04-17 (page 5)
# Scraped 20 rows from 2022-02-16–2022-04-17 (page 6)
# Scraped 20 rows from 2022-02-16–2022-04-17 (page 7)
# Scraped 20 rows from 2022-02-16–2022-04-17 (page 8)
# Scraped 1 rows from 2022-02-16–2022-04-17 (page 9)
# Scraped 0 rows from 2022-02-16–2022-04-17 (page 10)
# Quarter 2022-02-16_2022-04-17 appended to global dataset.
#
# Processing 2022-04-18 to 2022-06-17...
# Scraped 20 rows from 2022-04-18–2022-06-17 (page 1)
# Scraped 20 rows from 2022-04-18–2022-06-17 (page 2)
# Scraped 20 rows from 2022-04-18–2022-06-17 (page 3)
# Scraped 20 rows from 2022-04-18–2022-06-17 (page 4)
# Scraped 20 rows from 2022-04-18–2022-06-17 (page 5)
# Scraped 20 rows from 2022-04-18–2022-06-17 (page 6)
# Scraped 20 rows from 2022-04-18–2022-06-17 (page 7)
# Scraped 20 rows from 2022-04-18–2022-06-17 (page 8)
# Scraped 7 rows from 2022-04-18–2022-06-17 (page 9)
# Scraped 0 rows from 2022-04-18–2022-06-17 (page 10)
# Quarter 2022-04-18_2022-06-17 appended to global dataset.
#
# Processing 2022-06-18 to 2022-08-17...
# Scraped 20 rows from 2022-06-18–2022-08-17 (page 1)
# Scraped 20 rows from 2022-06-18–2022-08-17 (page 2)
# Scraped 20 rows from 2022-06-18–2022-08-17 (page 3)
# Scraped 20 rows from 2022-06-18–2022-08-17 (page 4)
# Scraped 20 rows from 2022-06-18–2022-08-17 (page 5)
# Scraped 20 rows from 2022-06-18–2022-08-17 (page 6)
# Scraped 20 rows from 2022-06-18–2022-08-17 (page 7)
# Scraped 20 rows from 2022-06-18–2022-08-17 (page 8)
# Scraped 20 rows from 2022-06-18–2022-08-17 (page 9)
# Scraped 10 rows from 2022-06-18–2022-08-17 (page 10)
# Scraped 0 rows from 2022-06-18–2022-08-17 (page 11)
# Quarter 2022-06-18_2022-08-17 appended to global dataset.
#
# Processing 2022-08-18 to 2022-10-17...
# Scraped 20 rows from 2022-08-18–2022-10-17 (page 1)
# Scraped 20 rows from 2022-08-18–2022-10-17 (page 2)
# Scraped 20 rows from 2022-08-18–2022-10-17 (page 3)
# Scraped 20 rows from 2022-08-18–2022-10-17 (page 4)
# Scraped 20 rows from 2022-08-18–2022-10-17 (page 5)
# Scraped 20 rows from 2022-08-18–2022-10-17 (page 6)
# Scraped 20 rows from 2022-08-18–2022-10-17 (page 7)
# Scraped 20 rows from 2022-08-18–2022-10-17 (page 8)
# Scraped 16 rows from 2022-08-18–2022-10-17 (page 9)
# Scraped 0 rows from 2022-08-18–2022-10-17 (page 10)
# Quarter 2022-08-18_2022-10-17 appended to global dataset.
#
# Processing 2022-10-18 to 2022-12-17...
# Scraped 20 rows from 2022-10-18–2022-12-17 (page 1)
# Scraped 20 rows from 2022-10-18–2022-12-17 (page 2)
# Scraped 20 rows from 2022-10-18–2022-12-17 (page 3)
# Scraped 20 rows from 2022-10-18–2022-12-17 (page 4)
# Scraped 20 rows from 2022-10-18–2022-12-17 (page 5)
# Scraped 20 rows from 2022-10-18–2022-12-17 (page 6)
# Scraped 2 rows from 2022-10-18–2022-12-17 (page 7)
# Scraped 0 rows from 2022-10-18–2022-12-17 (page 8)
# Quarter 2022-10-18_2022-12-17 appended to global dataset.
#
# Processing 2022-12-18 to 2023-02-16...
# Scraped 20 rows from 2022-12-18–2023-02-16 (page 1)
# Scraped 20 rows from 2022-12-18–2023-02-16 (page 2)
# Scraped 20 rows from 2022-12-18–2023-02-16 (page 3)
# Scraped 20 rows from 2022-12-18–2023-02-16 (page 4)
# Scraped 20 rows from 2022-12-18–2023-02-16 (page 5)
# Scraped 20 rows from 2022-12-18–2023-02-16 (page 6)
# Scraped 20 rows from 2022-12-18–2023-02-16 (page 7)
# Scraped 20 rows from 2022-12-18–2023-02-16 (page 8)
# Scraped 2 rows from 2022-12-18–2023-02-16 (page 9)
# Scraped 0 rows from 2022-12-18–2023-02-16 (page 10)
# Quarter 2022-12-18_2023-02-16 appended to global dataset.
#
# Processing 2023-02-17 to 2023-04-18...
# Scraped 20 rows from 2023-02-17–2023-04-18 (page 1)
# Scraped 20 rows from 2023-02-17–2023-04-18 (page 2)
# Scraped 20 rows from 2023-02-17–2023-04-18 (page 3)
# Scraped 20 rows from 2023-02-17–2023-04-18 (page 4)
# Scraped 20 rows from 2023-02-17–2023-04-18 (page 5)
# Scraped 20 rows from 2023-02-17–2023-04-18 (page 6)
# Scraped 20 rows from 2023-02-17–2023-04-18 (page 7)
# Scraped 20 rows from 2023-02-17–2023-04-18 (page 8)
# Scraped 20 rows from 2023-02-17–2023-04-18 (page 9)
# Scraped 13 rows from 2023-02-17–2023-04-18 (page 10)
# Scraped 0 rows from 2023-02-17–2023-04-18 (page 11)
# Quarter 2023-02-17_2023-04-18 appended to global dataset.
#
# Processing 2023-04-19 to 2023-06-18...
# Scraped 20 rows from 2023-04-19–2023-06-18 (page 1)
# Scraped 20 rows from 2023-04-19–2023-06-18 (page 2)
# Scraped 20 rows from 2023-04-19–2023-06-18 (page 3)
# Scraped 20 rows from 2023-04-19–2023-06-18 (page 4)
# Scraped 20 rows from 2023-04-19–2023-06-18 (page 5)
# Scraped 20 rows from 2023-04-19–2023-06-18 (page 6)
# Scraped 16 rows from 2023-04-19–2023-06-18 (page 7)
# Scraped 0 rows from 2023-04-19–2023-06-18 (page 8)
# Quarter 2023-04-19_2023-06-18 appended to global dataset.
#
# Processing 2023-06-19 to 2023-08-18...
# Scraped 20 rows from 2023-06-19–2023-08-18 (page 1)
# Scraped 20 rows from 2023-06-19–2023-08-18 (page 2)
# Scraped 20 rows from 2023-06-19–2023-08-18 (page 3)
# Scraped 20 rows from 2023-06-19–2023-08-18 (page 4)
# Scraped 20 rows from 2023-06-19–2023-08-18 (page 5)
# Scraped 20 rows from 2023-06-19–2023-08-18 (page 6)
# Scraped 20 rows from 2023-06-19–2023-08-18 (page 7)
# Scraped 20 rows from 2023-06-19–2023-08-18 (page 8)
# Scraped 4 rows from 2023-06-19–2023-08-18 (page 9)
# Scraped 0 rows from 2023-06-19–2023-08-18 (page 10)
# Quarter 2023-06-19_2023-08-18 appended to global dataset.
#
# Processing 2023-08-19 to 2023-10-18...
# Scraped 20 rows from 2023-08-19–2023-10-18 (page 1)
# Scraped 20 rows from 2023-08-19–2023-10-18 (page 2)
# Scraped 20 rows from 2023-08-19–2023-10-18 (page 3)
# Scraped 20 rows from 2023-08-19–2023-10-18 (page 4)
# Scraped 20 rows from 2023-08-19–2023-10-18 (page 5)
# Scraped 20 rows from 2023-08-19–2023-10-18 (page 6)
# Scraped 20 rows from 2023-08-19–2023-10-18 (page 7)
# Scraped 8 rows from 2023-08-19–2023-10-18 (page 8)
# Scraped 0 rows from 2023-08-19–2023-10-18 (page 9)
# Quarter 2023-08-19_2023-10-18 appended to global dataset.
#
# Processing 2023-10-19 to 2023-12-18...
# Scraped 20 rows from 2023-10-19–2023-12-18 (page 1)
# Scraped 20 rows from 2023-10-19–2023-12-18 (page 2)
# Scraped 20 rows from 2023-10-19–2023-12-18 (page 3)
# Scraped 10 rows from 2023-10-19–2023-12-18 (page 4)
# Scraped 0 rows from 2023-10-19–2023-12-18 (page 5)
# Quarter 2023-10-19_2023-12-18 appended to global dataset.
#
# Processing 2023-12-19 to 2024-02-17...
# Scraped 20 rows from 2023-12-19–2024-02-17 (page 1)
# Scraped 20 rows from 2023-12-19–2024-02-17 (page 2)
# Scraped 20 rows from 2023-12-19–2024-02-17 (page 3)
# Scraped 20 rows from 2023-12-19–2024-02-17 (page 4)
# Scraped 20 rows from 2023-12-19–2024-02-17 (page 5)
# Scraped 18 rows from 2023-12-19–2024-02-17 (page 6)
# Scraped 0 rows from 2023-12-19–2024-02-17 (page 7)
# Quarter 2023-12-19_2024-02-17 appended to global dataset.
#
# Processing 2024-02-18 to 2024-04-18...
# Scraped 20 rows from 2024-02-18–2024-04-18 (page 1)
# Scraped 20 rows from 2024-02-18–2024-04-18 (page 2)
# Scraped 20 rows from 2024-02-18–2024-04-18 (page 3)
# Scraped 20 rows from 2024-02-18–2024-04-18 (page 4)
# Scraped 20 rows from 2024-02-18–2024-04-18 (page 5)
# Scraped 20 rows from 2024-02-18–2024-04-18 (page 6)
# Scraped 20 rows from 2024-02-18–2024-04-18 (page 7)
# Scraped 7 rows from 2024-02-18–2024-04-18 (page 8)
# Scraped 0 rows from 2024-02-18–2024-04-18 (page 9)
# Quarter 2024-02-18_2024-04-18 appended to global dataset.
#
# Processing 2024-04-19 to 2024-06-18...
# Scraped 20 rows from 2024-04-19–2024-06-18 (page 1)
# Scraped 20 rows from 2024-04-19–2024-06-18 (page 2)
# Scraped 20 rows from 2024-04-19–2024-06-18 (page 3)
# Scraped 20 rows from 2024-04-19–2024-06-18 (page 4)
# Scraped 20 rows from 2024-04-19–2024-06-18 (page 5)
# Scraped 20 rows from 2024-04-19–2024-06-18 (page 6)
# Scraped 8 rows from 2024-04-19–2024-06-18 (page 7)
# Scraped 0 rows from 2024-04-19–2024-06-18 (page 8)
# Quarter 2024-04-19_2024-06-18 appended to global dataset.
#
# Processing 2024-06-19 to 2024-08-18...
# Scraped 20 rows from 2024-06-19–2024-08-18 (page 1)
# Scraped 20 rows from 2024-06-19–2024-08-18 (page 2)
# Scraped 20 rows from 2024-06-19–2024-08-18 (page 3)
# Scraped 20 rows from 2024-06-19–2024-08-18 (page 4)
# Scraped 20 rows from 2024-06-19–2024-08-18 (page 5)
# Scraped 12 rows from 2024-06-19–2024-08-18 (page 6)
# Scraped 0 rows from 2024-06-19–2024-08-18 (page 7)
# Quarter 2024-06-19_2024-08-18 appended to global dataset.
#
# Processing 2024-08-19 to 2024-10-18...
# Scraped 20 rows from 2024-08-19–2024-10-18 (page 1)
# Scraped 20 rows from 2024-08-19–2024-10-18 (page 2)
# Scraped 20 rows from 2024-08-19–2024-10-18 (page 3)
# Scraped 20 rows from 2024-08-19–2024-10-18 (page 4)
# Scraped 20 rows from 2024-08-19–2024-10-18 (page 5)
# Scraped 18 rows from 2024-08-19–2024-10-18 (page 6)
# Scraped 0 rows from 2024-08-19–2024-10-18 (page 7)
# Quarter 2024-08-19_2024-10-18 appended to global dataset.
#
# Processing 2024-10-19 to 2024-12-18...
# Scraped 20 rows from 2024-10-19–2024-12-18 (page 1)
# Scraped 20 rows from 2024-10-19–2024-12-18 (page 2)
# Scraped 20 rows from 2024-10-19–2024-12-18 (page 3)
# Scraped 20 rows from 2024-10-19–2024-12-18 (page 4)
# Scraped 20 rows from 2024-10-19–2024-12-18 (page 5)
# Scraped 10 rows from 2024-10-19–2024-12-18 (page 6)
# Scraped 0 rows from 2024-10-19–2024-12-18 (page 7)
# Quarter 2024-10-19_2024-12-18 appended to global dataset.
#
# Processing 2024-12-19 to 2024-12-31...
# Scraped 12 rows from 2024-12-19–2024-12-31 (page 1)
# Scraped 0 rows from 2024-12-19–2024-12-31 (page 2)
# Quarter 2024-12-19_2024-12-31 appended to global dataset.
#
# All quarters saved to 'nocheyniebla_casos_1999_2024.csv'.
#
# Complete!
